# %%
import json
import pandas as pd

# %%
data = pd.read_json('../data/poems_clustered2.json')

# %%
data.head()
# Out:
#                         author                          book  cluster  \
# 0            Théophile Gautier  La comédie de la mort (1838)        8
# 1            Antoine de Latour          La vie intime (1833)        2
# 2  Marceline Desbordes-Valmore               Romances (1830)        0
# 3        Alphonse de Lamartine  Méditations poétiques (1820)        8
# 4          Sophie d'Arbouville   Poésies et nouvelles (1840)        8
#
#                                      lemmatized_text  \
# 0  revenir , revenir , bien-aimé ! comme fleur lo...
# 1  dix an être passer , dix an ! la|le avoir revo...
# 2  quand cloche soir , lent volée , faire descend...
# 3  souvent montagne , ombre vieux chêne , Au couc...
# 4  quand horloge avoir sonner moment départ , Auc...
#
#                                            link_poem  \
# 0  http://www.poesie-francaise.fr/theophile-gauti...
# 1  http://www.poesie-francaise.fr/antoine-de-lato...
# 2  http://www.poesie-francaise.fr/marceline-desbo...
# ...
