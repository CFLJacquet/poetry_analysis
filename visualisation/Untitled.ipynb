# %%
import json
import pandas as pd

# %%
data = pd.read_json('../data/poems_clustered.json')

# %%
data.head()
# Out:
#    ID                 author                                      book  \
# 0   0  Alphonse de Lamartine            M̩ditations po̩tiques (1820)
# 1   1       Alfred de Musset                 Po̩sies posthumes (1888)
# 2   2       Alfred de Musset                       Po̬mes de jeunesse
# 3   3          R̩my Belleau                        La Bergerie (1565)
# 4   4            Victor Hugo  Les chansons des rues et des bois (1865)
#
#    cluster                                          link_poem  \
# 0        3  http://www.poesie-francaise.fr/alphonse-de-lam...
# 1        5  http://www.poesie-francaise.fr/alfred-de-musse...
# 2        5  http://www.poesie-francaise.fr/alfred-de-musse...
# 3        3  http://www.poesie-francaise.fr/remy-belleau/po...
# 4        5  http://www.poesie-francaise.fr/victor-hugo/poe...
#
#                                           link_theme  \
# 0     http://www.poesie-francaise.fr/poemes-absence/
# 1  http://www.poesie-francaise.fr/poemes-amour-am...
# ...
